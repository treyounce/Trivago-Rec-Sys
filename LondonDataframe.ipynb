# %% [markdown]
# ### London Notebook

# %%
import pandas as pd

# %%
df = pd.read_csv('london_df.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       user_id     session_id   timestamp  step    action_type  \
# 0         121  03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# 1         121  03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# 2         121  03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# 3         121  03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# 4         121  03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
#
#    reference platform                    city   device current_filters  price  \
# 0    1032816       UK  London, United Kingdom  desktop             NaN    104
# 1    1032816       UK  London, United Kingdom  desktop             NaN     92
# 2    1032816       UK  London, United Kingdom  desktop             NaN    100
# 3    1032816       UK  London, United Kingdom  desktop             NaN    103
# 4    1032816       UK  London, United Kingdom  desktop             NaN    102
#
#    impression
# 0       12693
# ...

# %% [markdown]
# ### Dropping index from previous dataframe created in EDA

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df
# Out:
#              user_id     session_id   timestamp  step    action_type  \
# 0       03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# 1       03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# 2       03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# 3       03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# 4       03K8AXBL4BX2  ec139e10b9238  1541100322     6  clickout item
# ...              ...            ...         ...   ...            ...
# 310962  YH5BH5INZMHX  068dcaa3b08b4  1541518492     1  clickout item
# 310963  YH5BH5INZMHX  068dcaa3b08b4  1541518492     1  clickout item
# 310964  YH5BH5INZMHX  068dcaa3b08b4  1541518492     1  clickout item
# 310965  YH5BH5INZMHX  068dcaa3b08b4  1541518492     1  clickout item
# 310966  YH5BH5INZMHX  068dcaa3b08b4  1541518492     1  clickout item
#
#         reference platform                    city   device current_filters  \
# ...
